# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.datasets import make_blobs

# %%
data = make_blobs(n_samples=200,n_features=2,centers=8,cluster_std=1.8,random_state=101)

# %%
plt.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='rainbow')

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=8)

# %%
kmeans.fit(data[0])
# Out:
# KMeans()

# %%
kmeans.cluster_centers_
# Out:
# array([[ 0.97628675, -2.54165902],
#        [ 9.31072911, -5.58182312],
#        [-6.95426312,  5.05702781],
#        [-9.76750125, -6.4197268 ],
#        [ 3.85048114,  6.9229514 ],
#        [ 4.36827251, -6.36220357],
#        [-4.07673748,  8.10391969],
#        [-0.13260486,  2.77107097]])

# %%
kmeans.labels_
# Out:
# array([6, 5, 5, 0, 0, 1, 6, 1, 3, 3, 1, 3, 6, 0, 0, 6, 7, 2, 4, 5, 3, 4,
#        0, 0, 6, 7, 7, 7, 2, 0, 1, 2, 0, 7, 6, 7, 6, 6, 3, 4, 7, 0, 3, 1,
#        0, 6, 0, 0, 3, 3, 5, 7, 4, 7, 0, 3, 5, 7, 1, 5, 0, 6, 1, 4, 1, 0,
#        3, 3, 4, 2, 5, 5, 0, 2, 1, 4, 1, 5, 1, 3, 6, 6, 7, 5, 2, 7, 6, 4,
#        2, 4, 5, 0, 0, 3, 1, 7, 3, 0, 5, 1, 5, 4, 5, 7, 3, 2, 1, 1, 4, 4,
#        2, 4, 6, 5, 1, 3, 4, 2, 2, 4, 0, 2, 3, 4, 7, 3, 2, 3, 6, 6, 1, 1,
#        3, 1, 7, 4, 6, 2, 6, 7, 2, 6, 7, 1, 2, 5, 5, 3, 7, 5, 4, 2, 1, 5,
#        3, 4, 1, 1, 6, 1, 7, 7, 3, 2, 2, 5, 0, 6, 0, 3, 5, 7, 3, 6, 4, 7,
#        7, 0, 6, 2, 7, 0, 7, 4, 5, 7, 7, 0, 7, 6, 0, 1, 1, 2, 4, 4, 1, 4,
#        6, 4])

# %%
fig , (ax1,ax2) = plt.subplots(1,2, sharey=True,figsize=(10,6))

ax1.set_title('K Means')
ax1.scatter(data[0][:,0],data[0][:,1],c=kmeans.labels_,cmap='rainbow')

ax2.set_title('Original')
ax2.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='rainbow')
